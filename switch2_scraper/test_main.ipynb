# %%
# Cell 1: Setup
import sys
sys.path.insert(0, '.')
from main import main  # Import main() function

# Cell 2: Test main()
print("TESTING main()...")
result = main()
print(f"main() completed! Got {len(result)} reviews")
# Out:
# TESTING main()...
# Scraping game lists...
# Page 1: 62 games
# Page 2: 62 games
# Page 3: 62 games
# Page 4: 62 games
# Page 5: 62 games
# Page 6: 62 games
# Page 7: 6 games
# Total: 378 games
#
# Scraping reviews...
# Processing Nintendo Switch 2 Games...
# Processing All Nintendo Switch 2 Games...
# Processing Pokémon PokopiaSwitch 2...
# Processing Yoshi and the Mysterious BookSwitch 2...
# Processing Pokémon Winds & WavesSwitch 2...
# Processing Resident Evil RequiemSwitch 2...
# Processing Super Mario Bros. Wonder - Nintendo Switch 2 Edition + Meetup In Bellabel ParkSwitch 2...
# Processing Xenoblade Chronicles X: Definitive Edition - Nintendo Switch 2 EditionSwitch 2...
# Processing Fallout 4: Anniversary EditionSwitch 2...
# Processing Metal Gear Solid: Master Collection Vol. 2Switch 2...
# Processing Fire Emblem: Fortune's WeaveSwitch 2...
# Processing Mario Tennis FeverSwitch 2...
# Processing The Disney Afternoon CollectionSwitch 2...
# ...
